# %% [markdown]
# <a href="https://colab.research.google.com/github/bhomik179/experiment-16/blob/main/exp16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bhomik V keshi
#
# 25070123172
#
# Symbiosis Institute of Technology,Pune
#
# **Experiment Number 16**
#
# **NLP Technique On text data in python**

# %%
# 1. Tokenization
import nltk

# Download required data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

text = "Natural Language processing is interesting"

tokens = word_tokenize(text)
print(tokens)
print()
# Out:
# ['Natural', 'Language', 'processing', 'is', 'interesting']

# %%
# Sentence Tokenization

from nltk.tokenize import sent_tokenize

text = " Python is easy. It is widely used in data science"

sentences = sent_tokenize(text)

print(sentences)
# Out:
# [' Python is easy.', 'It is widely used in data science']

# %%
#Stop Word Removal
#Stop words such as is, the, and, in are removed.


from nltk.corpus import stopwords
stop_words = set (stopwords.words ('english'))

words = word_tokenize(text)
filtered_words = [w for w in words if w. lower() not in stop_words]

print(filtered_words)
# Out:
# ['Python', 'easy', '.', 'widely', 'used', 'data', 'science']

# %%
#Stemming
# stemming reduces word to their root form

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ["running", 'runs', 'ran','coding','gone',"swimming","drinking"]

for w in words:
  print(stemmer.stem(w))
# Out:
# run
# run
# ran
# code
# gone
# swim
# drink

# %%
# lemnatization
# lemnatiztion converts wirds to their dictinary form

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("the"))
print(lemmatizer.lemmatize("bestest"))
print(lemmatizer.lemmatize("thing"))
print(lemmatizer.lemmatize("that"))
print(lemmatizer.lemmatize("have"))
print(lemmatizer.lemmatize("ever"))
print(lemmatizer.lemmatize("happened"))
print(lemmatizer.lemmatize("To"))
print(lemmatizer.lemmatize("me"))
print(lemmatizer.lemmatize("is"))
print(lemmatizer.lemmatize("you"))
# Out:
# the
# bestest
# thing
# that
# have
# ever
# happened
# To
# me
# is
# you

# %%
# lemnatization
# lemnatiztion converts wirds to their dictinary form

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("studies"))
print(lemmatizer.lemmatize("bestest"))
print(lemmatizer.lemmatize("best"))
print(lemmatizer.lemmatize("running"))
print(lemmatizer.lemmatize("coding"))
print(lemmatizer.lemmatize("ever"))
# Out:
# study
# bestest
# best
# running
# coding
# ever

# %%
# Part-of-speech (POS)Tagging

# pos tagging identifies grammatical roles of the word

import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
from nltk import pos_tag

words = word_tokenize("Python is a powerful Programming Language")
print(pos_tag(words))
# Out:
# [('Python', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('powerful', 'JJ'), ('Programming', 'NNP'), ('Language', 'NN')]

# %%
# Word frequency Count

from nltk.probability import FreqDist
words = word_tokenize(text)
freq_dist = FreqDist(words)

print(freq_dist.most_common())
# Out:
# [('is', 2), ('Python', 1), ('easy', 1), ('.', 1), ('It', 1), ('widely', 1), ('used', 1), ('in', 1), ('data', 1), ('science', 1)]
